# %%
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class Softloss(nn.Module):
    def __init__(self,T=4,loss_portion=[1,0,0]) -> None:
        '''
        T: temperature
        loss_portion: KLD, cosine, mse
        '''
        super(Softloss,self).__init__()
        self.T=T
        self.portion=loss_portion
    def forward(self,x,y):
        soft_x=F.log_softmax(x/self.T,dim=-1)
        soft_y=F.softmax(y/self.T,dim=-1)
        loss=self.portion[0]*F.kl_div(soft_x,soft_y,reduction="batchmean")\
            +self.portion[1]*F.cosine_embedding_loss(soft_x,soft_y,torch.ones(soft_x.shape[0]).to(soft_x.device))\
            +self.portion[2]*F.mse_loss(soft_x,soft_y)
        return loss*self.T*self.T

# %%
class Teacher(nn.Module):
    def __init__(self):
        super(Teacher, self).__init__()
        self.layers=nn.Sequential(nn.Flatten(),
                                    #nn.Dropout(0.2),
                                    nn.Linear(28*28,1200),
                                    #n.Dropout(0.5),
                                    nn.ReLU(),
                                    nn.Linear(1200,10))
    def forward(self,x):
        return self.layers(x)

# %%
class Student(nn.Module):
    def __init__(self):
        super(Student, self).__init__()
        self.layers=nn.Sequential(nn.Flatten(),
                                    nn.Linear(28*28,400),
                                    nn.ReLU(),
                                    nn.Linear(400,10))
    def forward(self,x):
        return self.layers(x)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform = transforms.Compose(
    
    (transforms.ToTensor(),)
    
)
transform_train = transforms.Compose(
    (
    
    transforms.RandomCrop((28,28),padding=2),
    #transforms.RandomHorizontalFlip(),
    #transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    #transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    
    #
    #transforms.ColorJitter(0.2,0,0)
    
    )
)

transform_val = transform
#############################################
# do NOT change these
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = MNIST(
    root=DATA_ROOT, 
    train=True, 
    download=True,
    transform=transform_train    # your code
)

val_set = MNIST(
    root=DATA_ROOT, 
    train=False, 
    download=True,
    transform=transform_val    # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size=TRAIN_BATCH_SIZE,  # your code
    shuffle=True,     # your code
    num_workers=2
)

val_loader = DataLoader(
    val_set, 
    batch_size=VAL_BATCH_SIZE,  # your code
    shuffle=False,     # your code
    num_workers=2
)
#############################################

# %%
import torch.nn as nn
import torch.optim as optim

# %%
def train(T,portion,alpha,train_loader,val_loader,EPOCHS=150):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    student=Teacher()
    student=student.to(device)
    model=student
    teacher=Student()
    state=torch.load("./saved_model/4.5114_distilled_9921.pth")["state_dict"]
    teacher.load_state_dict(state)
    teacher=teacher.to(device)
    state=None
    # some hyperparameters
    # total number of training epochs
    teacher.eval()
    # hyperparameters, do NOT change right now
    # initial learning rate
    INITIAL_LR = 0.1

    # momentum for optimizer
    MOMENTUM = 0.9

    # L2 regularization strength
    REG = 0.00
    criterion = nn.CrossEntropyLoss()

    # Add optimizer
    optimizer = optim.SGD(student.parameters(),lr=INITIAL_LR,momentum=MOMENTUM,nesterov=True)
    soft_criterion=Softloss(T,portion)
    # the folder where the trained model is saved
    CHECKPOINT_FOLDER = "./tmp_model"
    DECAY_EPOCHS=1
    DECAY=0.95
    # start the training/validation process
    # the process should take about 5 minutes on a GTX 1070-Ti
    # if the code is written efficiently.
    best_val_acc = 0
    current_learning_rate = INITIAL_LR
    
    print("==> Training starts!")
    print("="*50)
    for i in range(0, EPOCHS):
        # handle the learning rate scheduler.
        
        if i % DECAY_EPOCHS == 0 and i != 0 :
            current_learning_rate = current_learning_rate * DECAY
        
            for param_group in optimizer.param_groups:
                param_group['lr'] = current_learning_rate
            #print("Current learning rate has decayed to %f" %current_learning_rate)
        
        #######################
        # your code here
        # switch to train mode
        model.train()
        
        #######################
        
        print("Epoch %d:" %i)
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0 # track training loss if you want
        loader=train_loader
        
        # Train the model for 1 epoch.
        for batch_idx, (inputs, targets) in enumerate(loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs=inputs.to(device)
            targets=targets.to(device).long()

            
            # compute the output and loss
            out=model(inputs)
            with torch.no_grad():
                soft_target=teacher(inputs)
            loss=(1-alpha)*criterion(out,targets)+alpha*soft_criterion(out,soft_target)
            
            # zero the gradient
            
            optimizer.zero_grad()
            # backpropagation
            loss.backward()

            
            # apply gradient and update the weights
            optimizer.step()
            train_loss+=loss.item()
            
            # count the number of correctly predicted samples in the current batch
            correct_examples+=torch.sum(out.argmax(-1)==targets).item()
            ####################################
        total_examples=len(train_loader.dataset)      
        avg_loss = train_loss / len(train_loader)
        avg_acc = correct_examples / total_examples
        print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

        # Validate on the validation dataset
        #######################
        # your code here
        # switch to eval mode
        model.eval()
        
        #######################

        # this help you compute the validation accuracy
        total_examples = 0
        correct_examples = 0
        
        val_loss = 0 # again, track the validation loss if you want

        # disable gradient during validation, which can save GPU memory
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                ####################################
                # your code here
                # copy inputs to device
                inputs=inputs.to(device)
                targets=targets.to(device).long()
                # compute the output and loss
                out=model(inputs)
                loss=criterion(out,targets)
                # count the number of correctly predicted samples in the current batch
                val_loss+=loss.item()
                correct_examples+=torch.sum(out.argmax(-1)==targets).item()
                
                ####################################
        total_examples=len(val_loader.dataset)
        avg_loss = val_loss / len(val_loader)
        avg_acc = correct_examples / total_examples
        print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
        
        # save the model checkpoint
        if avg_acc > best_val_acc:
            best_val_acc = avg_acc
            if not os.path.exists(CHECKPOINT_FOLDER):
                os.makedirs(CHECKPOINT_FOLDER)
            print("Saving ...")
            state = {'state_dict': model.state_dict(),
                    'epoch': i,
                    }
            torch.save(state, os.path.join(CHECKPOINT_FOLDER, str(T)+'_distilled.pth'))
            

    print("="*50)
    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
    return best_val_acc

# %%
train(4,[1,0,0],1,train_loader,val_loader)
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.8436, Training accuracy: 0.9232
# Validation loss: 0.0498, Validation accuracy: 0.9830
# Saving ...
# Epoch 1:
# Training loss: 0.2759, Training accuracy: 0.9814
# Validation loss: 0.0365, Validation accuracy: 0.9872
# Saving ...
# Epoch 2:
# Training loss: 0.1772, Training accuracy: 0.9845
# Validation loss: 0.0347, Validation accuracy: 0.9884
# Saving ...
# Epoch 3:
# Training loss: 0.1364, Training accuracy: 0.9868
# Validation loss: 0.0325, Validation accuracy: 0.9886
# Saving ...
# Epoch 4:
# Training loss: 0.1137, Training accuracy: 0.9883
# Validation loss: 0.0322, Validation accuracy: 0.9883
# Epoch 5:
# Training loss: 0.0984, Training accuracy: 0.9888
# Validation loss: 0.0308, Validation accuracy: 0.9894
# Saving ...
# Epoch 6:
# Training loss: 0.0874, Training accuracy: 0.9894
# Validation loss: 0.0305, Validation accuracy: 0.9895
# Saving ...
# Epoch 7:
# Training loss: 0.0793, Training accuracy: 0.9898
# Validation loss: 0.0297, Validation accuracy: 0.9891
# Epoch 8:
# Training loss: 0.0721, Training accuracy: 0.9899
# Validation loss: 0.0301, Validation accuracy: 0.9900
# Saving ...
# Epoch 9:
# Training loss: 0.0671, Training accuracy: 0.9905
# Validation loss: 0.0301, Validation accuracy: 0.9892
# Epoch 10:
# Training loss: 0.0630, Training accuracy: 0.9901
# Validation loss: 0.0287, Validation accuracy: 0.9904
# Saving ...
# Epoch 11:
# Training loss: 0.0590, Training accuracy: 0.9905
# Validation loss: 0.0291, Validation accuracy: 0.9897
# Epoch 12:
# Training loss: 0.0558, Training accuracy: 0.9905
# Validation loss: 0.0284, Validation accuracy: 0.9907
# Saving ...
# Epoch 13:
# Training loss: 0.0527, Training accuracy: 0.9902
# Validation loss: 0.0284, Validation accuracy: 0.9906
# Epoch 14:
# Training loss: 0.0501, Training accuracy: 0.9908
# Validation loss: 0.0289, Validation accuracy: 0.9903
# Epoch 15:
# Training loss: 0.0478, Training accuracy: 0.9906
# Validation loss: 0.0283, Validation accuracy: 0.9904
# Epoch 16:
# Training loss: 0.0459, Training accuracy: 0.9911
# Validation loss: 0.0281, Validation accuracy: 0.9904
# Epoch 17:
# Training loss: 0.0445, Training accuracy: 0.9909
# Validation loss: 0.0278, Validation accuracy: 0.9907
# Epoch 18:
# Training loss: 0.0425, Training accuracy: 0.9908
# Validation loss: 0.0284, Validation accuracy: 0.9907
# Epoch 19:
# Training loss: 0.0415, Training accuracy: 0.9911
# Validation loss: 0.0273, Validation accuracy: 0.9909
# Saving ...
# Epoch 20:
# Training loss: 0.0398, Training accuracy: 0.9912
# Validation loss: 0.0278, Validation accuracy: 0.9910
# Saving ...
# Epoch 21:
# Training loss: 0.0389, Training accuracy: 0.9910
# Validation loss: 0.0274, Validation accuracy: 0.9909
# Epoch 22:
# Training loss: 0.0376, Training accuracy: 0.9910
# Validation loss: 0.0276, Validation accuracy: 0.9912
# Saving ...
# Epoch 23:
# Training loss: 0.0365, Training accuracy: 0.9907
# Validation loss: 0.0275, Validation accuracy: 0.9910
# Epoch 24:
# Training loss: 0.0359, Training accuracy: 0.9912
# Validation loss: 0.0271, Validation accuracy: 0.9910
# Epoch 25:
# Training loss: 0.0352, Training accuracy: 0.9911
# Validation loss: 0.0273, Validation accuracy: 0.9913
# Saving ...
# Epoch 26:
# Training loss: 0.0341, Training accuracy: 0.9911
# Validation loss: 0.0272, Validation accuracy: 0.9911
# Epoch 27:
# Training loss: 0.0338, Training accuracy: 0.9911
# Validation loss: 0.0272, Validation accuracy: 0.9908
# Epoch 28:
# Training loss: 0.0329, Training accuracy: 0.9911
# Validation loss: 0.0270, Validation accuracy: 0.9908
# Epoch 29:
# Training loss: 0.0321, Training accuracy: 0.9913
# Validation loss: 0.0269, Validation accuracy: 0.9913
# Epoch 30:
# Training loss: 0.0316, Training accuracy: 0.9911
# Validation loss: 0.0272, Validation accuracy: 0.9909
# Epoch 31:
# Training loss: 0.0311, Training accuracy: 0.9914
# Validation loss: 0.0269, Validation accuracy: 0.9912
# Epoch 32:
# Training loss: 0.0307, Training accuracy: 0.9911
# Validation loss: 0.0269, Validation accuracy: 0.9914
# Saving ...
# Epoch 33:
# Training loss: 0.0301, Training accuracy: 0.9912
# Validation loss: 0.0270, Validation accuracy: 0.9913
# Epoch 34:
# Training loss: 0.0298, Training accuracy: 0.9917
# Validation loss: 0.0267, Validation accuracy: 0.9915
# Saving ...
# Epoch 35:
# Training loss: 0.0293, Training accuracy: 0.9913
# Validation loss: 0.0271, Validation accuracy: 0.9910
# Epoch 36:
# Training loss: 0.0289, Training accuracy: 0.9912
# Validation loss: 0.0269, Validation accuracy: 0.9910
# Epoch 37:
# Training loss: 0.0288, Training accuracy: 0.9915
# Validation loss: 0.0266, Validation accuracy: 0.9913
# Epoch 38:
# Training loss: 0.0284, Training accuracy: 0.9914
# Validation loss: 0.0269, Validation accuracy: 0.9913
# Epoch 39:
# Training loss: 0.0279, Training accuracy: 0.9915
# Validation loss: 0.0267, Validation accuracy: 0.9911
# Epoch 40:
# Training loss: 0.0276, Training accuracy: 0.9917
# Validation loss: 0.0268, Validation accuracy: 0.9912
# Epoch 41:
# Training loss: 0.0272, Training accuracy: 0.9919
# Validation loss: 0.0269, Validation accuracy: 0.9913
# Epoch 42:
# Training loss: 0.0270, Training accuracy: 0.9914
# Validation loss: 0.0268, Validation accuracy: 0.9914
# Epoch 43:
# Training loss: 0.0268, Training accuracy: 0.9918
# Validation loss: 0.0268, Validation accuracy: 0.9913
# Epoch 44:
# Training loss: 0.0267, Training accuracy: 0.9911
# Validation loss: 0.0267, Validation accuracy: 0.9911
# Epoch 45:
# Training loss: 0.0265, Training accuracy: 0.9910
# Validation loss: 0.0268, Validation accuracy: 0.9909
# Epoch 46:
# Training loss: 0.0262, Training accuracy: 0.9918
# Validation loss: 0.0268, Validation accuracy: 0.9912
# Epoch 47:
# Training loss: 0.0262, Training accuracy: 0.9917
# Validation loss: 0.0267, Validation accuracy: 0.9914
# Epoch 48:
# Training loss: 0.0260, Training accuracy: 0.9916
# Validation loss: 0.0267, Validation accuracy: 0.9909
# Epoch 49:
# Training loss: 0.0256, Training accuracy: 0.9915
# Validation loss: 0.0266, Validation accuracy: 0.9908
# Epoch 50:
# Training loss: 0.0255, Training accuracy: 0.9916
# Validation loss: 0.0267, Validation accuracy: 0.9910
# Epoch 51:
# Training loss: 0.0255, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 52:
# Training loss: 0.0253, Training accuracy: 0.9920
# Validation loss: 0.0265, Validation accuracy: 0.9910
# Epoch 53:
# Training loss: 0.0251, Training accuracy: 0.9914
# Validation loss: 0.0267, Validation accuracy: 0.9910
# Epoch 54:
# Training loss: 0.0249, Training accuracy: 0.9917
# Validation loss: 0.0266, Validation accuracy: 0.9912
# Epoch 55:
# Training loss: 0.0247, Training accuracy: 0.9914
# Validation loss: 0.0267, Validation accuracy: 0.9913
# Epoch 56:
# Training loss: 0.0247, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 57:
# Training loss: 0.0246, Training accuracy: 0.9914
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 58:
# Training loss: 0.0245, Training accuracy: 0.9909
# Validation loss: 0.0267, Validation accuracy: 0.9910
# Epoch 59:
# Training loss: 0.0246, Training accuracy: 0.9916
# Validation loss: 0.0266, Validation accuracy: 0.9911
# Epoch 60:
# Training loss: 0.0244, Training accuracy: 0.9918
# Validation loss: 0.0267, Validation accuracy: 0.9911
# Epoch 61:
# Training loss: 0.0242, Training accuracy: 0.9915
# Validation loss: 0.0267, Validation accuracy: 0.9911
# Epoch 62:
# Training loss: 0.0244, Training accuracy: 0.9913
# Validation loss: 0.0266, Validation accuracy: 0.9914
# Epoch 63:
# Training loss: 0.0240, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 64:
# Training loss: 0.0240, Training accuracy: 0.9915
# Validation loss: 0.0266, Validation accuracy: 0.9910
# Epoch 65:
# Training loss: 0.0240, Training accuracy: 0.9916
# Validation loss: 0.0266, Validation accuracy: 0.9912
# Epoch 66:
# Training loss: 0.0240, Training accuracy: 0.9913
# Validation loss: 0.0266, Validation accuracy: 0.9913
# Epoch 67:
# Training loss: 0.0238, Training accuracy: 0.9908
# Validation loss: 0.0266, Validation accuracy: 0.9915
# Epoch 68:
# Training loss: 0.0238, Training accuracy: 0.9911
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 69:
# Training loss: 0.0237, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 70:
# Training loss: 0.0237, Training accuracy: 0.9917
# Validation loss: 0.0267, Validation accuracy: 0.9910
# Epoch 71:
# Training loss: 0.0237, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 72:
# Training loss: 0.0235, Training accuracy: 0.9917
# Validation loss: 0.0266, Validation accuracy: 0.9911
# Epoch 73:
# Training loss: 0.0236, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 74:
# Training loss: 0.0234, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 75:
# Training loss: 0.0234, Training accuracy: 0.9916
# Validation loss: 0.0266, Validation accuracy: 0.9912
# Epoch 76:
# Training loss: 0.0235, Training accuracy: 0.9919
# Validation loss: 0.0266, Validation accuracy: 0.9913
# Epoch 77:
# Training loss: 0.0233, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 78:
# Training loss: 0.0233, Training accuracy: 0.9917
# Validation loss: 0.0266, Validation accuracy: 0.9914
# Epoch 79:
# Training loss: 0.0233, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 80:
# Training loss: 0.0235, Training accuracy: 0.9912
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 81:
# Training loss: 0.0233, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 82:
# Training loss: 0.0232, Training accuracy: 0.9915
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 83:
# Training loss: 0.0233, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 84:
# Training loss: 0.0231, Training accuracy: 0.9920
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 85:
# Training loss: 0.0232, Training accuracy: 0.9916
# Validation loss: 0.0266, Validation accuracy: 0.9914
# Epoch 86:
# Training loss: 0.0231, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 87:
# Training loss: 0.0232, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 88:
# Training loss: 0.0231, Training accuracy: 0.9921
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 89:
# Training loss: 0.0230, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 90:
# Training loss: 0.0230, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 91:
# Training loss: 0.0230, Training accuracy: 0.9920
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 92:
# Training loss: 0.0231, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 93:
# Training loss: 0.0233, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 94:
# Training loss: 0.0232, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 95:
# Training loss: 0.0230, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 96:
# Training loss: 0.0229, Training accuracy: 0.9915
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 97:
# Training loss: 0.0228, Training accuracy: 0.9923
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 98:
# Training loss: 0.0230, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 99:
# Training loss: 0.0231, Training accuracy: 0.9915
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 100:
# Training loss: 0.0228, Training accuracy: 0.9915
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 101:
# Training loss: 0.0229, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 102:
# Training loss: 0.0228, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 103:
# Training loss: 0.0231, Training accuracy: 0.9915
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 104:
# Training loss: 0.0229, Training accuracy: 0.9914
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 105:
# Training loss: 0.0230, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 106:
# Training loss: 0.0228, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 107:
# Training loss: 0.0228, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 108:
# Training loss: 0.0230, Training accuracy: 0.9924
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 109:
# Training loss: 0.0228, Training accuracy: 0.9917
# Validation loss: 0.0264, Validation accuracy: 0.9912
# Epoch 110:
# Training loss: 0.0229, Training accuracy: 0.9921
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 111:
# Training loss: 0.0228, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 112:
# Training loss: 0.0230, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 113:
# Training loss: 0.0229, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 114:
# Training loss: 0.0229, Training accuracy: 0.9914
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 115:
# Training loss: 0.0229, Training accuracy: 0.9915
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 116:
# Training loss: 0.0230, Training accuracy: 0.9923
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 117:
# Training loss: 0.0228, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 118:
# Training loss: 0.0228, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 119:
# Training loss: 0.0229, Training accuracy: 0.9915
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 120:
# Training loss: 0.0228, Training accuracy: 0.9921
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 121:
# Training loss: 0.0228, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 122:
# Training loss: 0.0227, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 123:
# Training loss: 0.0227, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 124:
# Training loss: 0.0226, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 125:
# Training loss: 0.0228, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 126:
# Training loss: 0.0228, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 127:
# Training loss: 0.0228, Training accuracy: 0.9915
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 128:
# Training loss: 0.0228, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 129:
# Training loss: 0.0227, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 130:
# Training loss: 0.0228, Training accuracy: 0.9913
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 131:
# Training loss: 0.0230, Training accuracy: 0.9919
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 132:
# Training loss: 0.0227, Training accuracy: 0.9913
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 133:
# Training loss: 0.0227, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 134:
# Training loss: 0.0228, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 135:
# Training loss: 0.0228, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9914
# Epoch 136:
# Training loss: 0.0227, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 137:
# Training loss: 0.0226, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 138:
# Training loss: 0.0227, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 139:
# Training loss: 0.0226, Training accuracy: 0.9913
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 140:
# Training loss: 0.0227, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 141:
# Training loss: 0.0226, Training accuracy: 0.9914
# Validation loss: 0.0265, Validation accuracy: 0.9913
# Epoch 142:
# Training loss: 0.0227, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9912
# Epoch 143:
# Training loss: 0.0227, Training accuracy: 0.9920
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 144:
# Training loss: 0.0227, Training accuracy: 0.9916
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 145:
# Training loss: 0.0228, Training accuracy: 0.9914
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 146:
# Training loss: 0.0229, Training accuracy: 0.9920
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 147:
# Training loss: 0.0227, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 148:
# Training loss: 0.0228, Training accuracy: 0.9918
# Validation loss: 0.0265, Validation accuracy: 0.9911
# Epoch 149:
# Training loss: 0.0226, Training accuracy: 0.9917
# Validation loss: 0.0265, Validation accuracy: 0.9911
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9915
# 0.9915

# %%
train(3,[1,0,0],1,train_loader,val_loader)
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.3589, Training accuracy: 0.9217
# Validation loss: 0.0491, Validation accuracy: 0.9833
# Saving ...
# Epoch 1:
# Training loss: 0.2146, Training accuracy: 0.9794
# Validation loss: 0.0383, Validation accuracy: 0.9860
# Saving ...
# Epoch 2:
# Training loss: 0.1284, Training accuracy: 0.9842
# Validation loss: 0.0320, Validation accuracy: 0.9893
# Saving ...
# Epoch 3:
# Training loss: 0.0932, Training accuracy: 0.9870
# Validation loss: 0.0289, Validation accuracy: 0.9895
# Saving ...
# Epoch 4:
# Training loss: 0.0787, Training accuracy: 0.9873
# Validation loss: 0.0298, Validation accuracy: 0.9895
# Epoch 5:
# Training loss: 0.0667, Training accuracy: 0.9884
# Validation loss: 0.0274, Validation accuracy: 0.9901
# Saving ...
# Epoch 6:
# Training loss: 0.0583, Training accuracy: 0.9892
# Validation loss: 0.0261, Validation accuracy: 0.9914
# Saving ...
# Epoch 7:
# Training loss: 0.0529, Training accuracy: 0.9895
# Validation loss: 0.0280, Validation accuracy: 0.9910
# Epoch 8:
# Training loss: 0.0490, Training accuracy: 0.9892
# Validation loss: 0.0267, Validation accuracy: 0.9907
# Epoch 9:
# Training loss: 0.0450, Training accuracy: 0.9900
# Validation loss: 0.0267, Validation accuracy: 0.9902
# Epoch 10:
# Training loss: 0.0420, Training accuracy: 0.9900
# Validation loss: 0.0258, Validation accuracy: 0.9913
# Epoch 11:
# Training loss: 0.0395, Training accuracy: 0.9903
# Validation loss: 0.0258, Validation accuracy: 0.9912
# Epoch 12:
# Training loss: 0.0374, Training accuracy: 0.9904
# Validation loss: 0.0260, Validation accuracy: 0.9906
# Epoch 13:
# Training loss: 0.0354, Training accuracy: 0.9907
# Validation loss: 0.0256, Validation accuracy: 0.9905
# Epoch 14:
# Training loss: 0.0338, Training accuracy: 0.9906
# Validation loss: 0.0265, Validation accuracy: 0.9907
# Epoch 15:
# Training loss: 0.0326, Training accuracy: 0.9909
# Validation loss: 0.0259, Validation accuracy: 0.9911
# Epoch 16:
# Training loss: 0.0316, Training accuracy: 0.9911
# Validation loss: 0.0258, Validation accuracy: 0.9910
# Epoch 17:
# Training loss: 0.0299, Training accuracy: 0.9910
# Validation loss: 0.0258, Validation accuracy: 0.9908
# Epoch 18:
# Training loss: 0.0292, Training accuracy: 0.9910
# Validation loss: 0.0254, Validation accuracy: 0.9909
# Epoch 19:
# Training loss: 0.0281, Training accuracy: 0.9914
# Validation loss: 0.0252, Validation accuracy: 0.9909
# Epoch 20:
# Training loss: 0.0278, Training accuracy: 0.9912
# Validation loss: 0.0254, Validation accuracy: 0.9915
# Saving ...
# Epoch 21:
# Training loss: 0.0268, Training accuracy: 0.9911
# Validation loss: 0.0256, Validation accuracy: 0.9908
# Epoch 22:
# Training loss: 0.0262, Training accuracy: 0.9912
# Validation loss: 0.0258, Validation accuracy: 0.9906
# Epoch 23:
# Training loss: 0.0253, Training accuracy: 0.9913
# Validation loss: 0.0255, Validation accuracy: 0.9914
# Epoch 24:
# Training loss: 0.0248, Training accuracy: 0.9914
# Validation loss: 0.0252, Validation accuracy: 0.9912
# Epoch 25:
# Training loss: 0.0242, Training accuracy: 0.9912
# Validation loss: 0.0256, Validation accuracy: 0.9908
# Epoch 26:
# Training loss: 0.0238, Training accuracy: 0.9909
# Validation loss: 0.0252, Validation accuracy: 0.9913
# Epoch 27:
# Training loss: 0.0233, Training accuracy: 0.9910
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 28:
# Training loss: 0.0230, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 29:
# Training loss: 0.0228, Training accuracy: 0.9914
# Validation loss: 0.0257, Validation accuracy: 0.9906
# Epoch 30:
# Training loss: 0.0224, Training accuracy: 0.9915
# Validation loss: 0.0257, Validation accuracy: 0.9908
# Epoch 31:
# Training loss: 0.0219, Training accuracy: 0.9914
# Validation loss: 0.0253, Validation accuracy: 0.9913
# Epoch 32:
# Training loss: 0.0215, Training accuracy: 0.9915
# Validation loss: 0.0253, Validation accuracy: 0.9907
# Epoch 33:
# Training loss: 0.0212, Training accuracy: 0.9915
# Validation loss: 0.0253, Validation accuracy: 0.9911
# Epoch 34:
# Training loss: 0.0210, Training accuracy: 0.9913
# Validation loss: 0.0253, Validation accuracy: 0.9907
# Epoch 35:
# Training loss: 0.0209, Training accuracy: 0.9916
# Validation loss: 0.0253, Validation accuracy: 0.9912
# Epoch 36:
# Training loss: 0.0205, Training accuracy: 0.9915
# Validation loss: 0.0256, Validation accuracy: 0.9910
# Epoch 37:
# Training loss: 0.0203, Training accuracy: 0.9918
# Validation loss: 0.0254, Validation accuracy: 0.9906
# Epoch 38:
# Training loss: 0.0202, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9912
# Epoch 39:
# Training loss: 0.0199, Training accuracy: 0.9914
# Validation loss: 0.0251, Validation accuracy: 0.9910
# Epoch 40:
# Training loss: 0.0196, Training accuracy: 0.9913
# Validation loss: 0.0253, Validation accuracy: 0.9906
# Epoch 41:
# Training loss: 0.0196, Training accuracy: 0.9912
# Validation loss: 0.0252, Validation accuracy: 0.9911
# Epoch 42:
# Training loss: 0.0196, Training accuracy: 0.9921
# Validation loss: 0.0254, Validation accuracy: 0.9913
# Epoch 43:
# Training loss: 0.0193, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9909
# Epoch 44:
# Training loss: 0.0192, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 45:
# Training loss: 0.0190, Training accuracy: 0.9914
# Validation loss: 0.0253, Validation accuracy: 0.9907
# Epoch 46:
# Training loss: 0.0189, Training accuracy: 0.9916
# Validation loss: 0.0251, Validation accuracy: 0.9908
# Epoch 47:
# Training loss: 0.0188, Training accuracy: 0.9917
# Validation loss: 0.0254, Validation accuracy: 0.9907
# Epoch 48:
# Training loss: 0.0188, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9904
# Epoch 49:
# Training loss: 0.0184, Training accuracy: 0.9918
# Validation loss: 0.0254, Validation accuracy: 0.9905
# Epoch 50:
# Training loss: 0.0183, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 51:
# Training loss: 0.0185, Training accuracy: 0.9914
# Validation loss: 0.0252, Validation accuracy: 0.9909
# Epoch 52:
# Training loss: 0.0183, Training accuracy: 0.9916
# Validation loss: 0.0250, Validation accuracy: 0.9905
# Epoch 53:
# Training loss: 0.0181, Training accuracy: 0.9919
# Validation loss: 0.0253, Validation accuracy: 0.9905
# Epoch 54:
# Training loss: 0.0181, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9910
# Epoch 55:
# Training loss: 0.0181, Training accuracy: 0.9918
# Validation loss: 0.0254, Validation accuracy: 0.9907
# Epoch 56:
# Training loss: 0.0179, Training accuracy: 0.9919
# Validation loss: 0.0253, Validation accuracy: 0.9907
# Epoch 57:
# Training loss: 0.0179, Training accuracy: 0.9923
# Validation loss: 0.0251, Validation accuracy: 0.9906
# Epoch 58:
# Training loss: 0.0179, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 59:
# Training loss: 0.0179, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 60:
# Training loss: 0.0177, Training accuracy: 0.9916
# Validation loss: 0.0251, Validation accuracy: 0.9908
# Epoch 61:
# Training loss: 0.0177, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9909
# Epoch 62:
# Training loss: 0.0176, Training accuracy: 0.9918
# Validation loss: 0.0254, Validation accuracy: 0.9909
# Epoch 63:
# Training loss: 0.0176, Training accuracy: 0.9914
# Validation loss: 0.0251, Validation accuracy: 0.9909
# Epoch 64:
# Training loss: 0.0176, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 65:
# Training loss: 0.0176, Training accuracy: 0.9915
# Validation loss: 0.0253, Validation accuracy: 0.9911
# Epoch 66:
# Training loss: 0.0174, Training accuracy: 0.9919
# Validation loss: 0.0253, Validation accuracy: 0.9912
# Epoch 67:
# Training loss: 0.0174, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9909
# Epoch 68:
# Training loss: 0.0173, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 69:
# Training loss: 0.0173, Training accuracy: 0.9921
# Validation loss: 0.0252, Validation accuracy: 0.9909
# Epoch 70:
# Training loss: 0.0174, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 71:
# Training loss: 0.0173, Training accuracy: 0.9911
# Validation loss: 0.0252, Validation accuracy: 0.9906
# Epoch 72:
# Training loss: 0.0171, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9906
# Epoch 73:
# Training loss: 0.0171, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 74:
# Training loss: 0.0171, Training accuracy: 0.9915
# Validation loss: 0.0253, Validation accuracy: 0.9906
# Epoch 75:
# Training loss: 0.0171, Training accuracy: 0.9919
# Validation loss: 0.0251, Validation accuracy: 0.9905
# Epoch 76:
# Training loss: 0.0170, Training accuracy: 0.9918
# Validation loss: 0.0253, Validation accuracy: 0.9905
# Epoch 77:
# Training loss: 0.0172, Training accuracy: 0.9915
# Validation loss: 0.0253, Validation accuracy: 0.9905
# Epoch 78:
# Training loss: 0.0172, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 79:
# Training loss: 0.0171, Training accuracy: 0.9921
# Validation loss: 0.0253, Validation accuracy: 0.9904
# Epoch 80:
# Training loss: 0.0170, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9909
# Epoch 81:
# Training loss: 0.0169, Training accuracy: 0.9915
# Validation loss: 0.0253, Validation accuracy: 0.9905
# Epoch 82:
# Training loss: 0.0171, Training accuracy: 0.9921
# Validation loss: 0.0253, Validation accuracy: 0.9906
# Epoch 83:
# Training loss: 0.0171, Training accuracy: 0.9916
# Validation loss: 0.0253, Validation accuracy: 0.9906
# Epoch 84:
# Training loss: 0.0168, Training accuracy: 0.9914
# Validation loss: 0.0252, Validation accuracy: 0.9904
# Epoch 85:
# Training loss: 0.0170, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9906
# Epoch 86:
# Training loss: 0.0169, Training accuracy: 0.9914
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 87:
# Training loss: 0.0169, Training accuracy: 0.9915
# Validation loss: 0.0251, Validation accuracy: 0.9907
# Epoch 88:
# Training loss: 0.0169, Training accuracy: 0.9923
# Validation loss: 0.0252, Validation accuracy: 0.9906
# Epoch 89:
# Training loss: 0.0170, Training accuracy: 0.9915
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 90:
# Training loss: 0.0169, Training accuracy: 0.9915
# Validation loss: 0.0252, Validation accuracy: 0.9905
# Epoch 91:
# Training loss: 0.0169, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 92:
# Training loss: 0.0169, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9906
# Epoch 93:
# Training loss: 0.0169, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 94:
# Training loss: 0.0168, Training accuracy: 0.9921
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 95:
# Training loss: 0.0168, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 96:
# Training loss: 0.0167, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 97:
# Training loss: 0.0168, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9906
# Epoch 98:
# Training loss: 0.0167, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9906
# Epoch 99:
# Training loss: 0.0168, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 100:
# Training loss: 0.0167, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9906
# Epoch 101:
# Training loss: 0.0166, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 102:
# Training loss: 0.0168, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 103:
# Training loss: 0.0167, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 104:
# Training loss: 0.0168, Training accuracy: 0.9914
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 105:
# Training loss: 0.0167, Training accuracy: 0.9914
# Validation loss: 0.0251, Validation accuracy: 0.9907
# Epoch 106:
# Training loss: 0.0168, Training accuracy: 0.9915
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 107:
# Training loss: 0.0167, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 108:
# Training loss: 0.0168, Training accuracy: 0.9915
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 109:
# Training loss: 0.0168, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 110:
# Training loss: 0.0169, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 111:
# Training loss: 0.0167, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 112:
# Training loss: 0.0168, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 113:
# Training loss: 0.0168, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 114:
# Training loss: 0.0168, Training accuracy: 0.9919
# Validation loss: 0.0251, Validation accuracy: 0.9907
# Epoch 115:
# Training loss: 0.0169, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 116:
# Training loss: 0.0167, Training accuracy: 0.9913
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 117:
# Training loss: 0.0168, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 118:
# Training loss: 0.0167, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 119:
# Training loss: 0.0168, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 120:
# Training loss: 0.0166, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 121:
# Training loss: 0.0166, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 122:
# Training loss: 0.0167, Training accuracy: 0.9921
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 123:
# Training loss: 0.0167, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 124:
# Training loss: 0.0168, Training accuracy: 0.9919
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 125:
# Training loss: 0.0168, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9909
# Epoch 126:
# Training loss: 0.0166, Training accuracy: 0.9923
# Validation loss: 0.0251, Validation accuracy: 0.9907
# Epoch 127:
# Training loss: 0.0168, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 128:
# Training loss: 0.0167, Training accuracy: 0.9915
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 129:
# Training loss: 0.0167, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 130:
# Training loss: 0.0167, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 131:
# Training loss: 0.0169, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 132:
# Training loss: 0.0167, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 133:
# Training loss: 0.0167, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 134:
# Training loss: 0.0167, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 135:
# Training loss: 0.0169, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 136:
# Training loss: 0.0168, Training accuracy: 0.9916
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 137:
# Training loss: 0.0168, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 138:
# Training loss: 0.0166, Training accuracy: 0.9915
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 139:
# Training loss: 0.0167, Training accuracy: 0.9920
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 140:
# Training loss: 0.0167, Training accuracy: 0.9915
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 141:
# Training loss: 0.0167, Training accuracy: 0.9915
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 142:
# Training loss: 0.0166, Training accuracy: 0.9922
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 143:
# Training loss: 0.0167, Training accuracy: 0.9918
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 144:
# Training loss: 0.0167, Training accuracy: 0.9922
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 145:
# Training loss: 0.0167, Training accuracy: 0.9923
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 146:
# Training loss: 0.0167, Training accuracy: 0.9921
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 147:
# Training loss: 0.0168, Training accuracy: 0.9921
# Validation loss: 0.0252, Validation accuracy: 0.9907
# Epoch 148:
# Training loss: 0.0168, Training accuracy: 0.9913
# Validation loss: 0.0252, Validation accuracy: 0.9908
# Epoch 149:
# Training loss: 0.0167, Training accuracy: 0.9917
# Validation loss: 0.0252, Validation accuracy: 0.9908
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9915
# 0.9915
